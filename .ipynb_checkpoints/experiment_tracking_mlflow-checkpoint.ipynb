# %%
import warnings

import pandas as pd
import numpy as np
from sklearn.metrics import mean_squared_error, mean_absolute_error, r2_score
from sklearn.model_selection import train_test_split
from sklearn.model_selection import ParameterGrid
from sklearn.ensemble import RandomForestClassifier, GradientBoostingClassifier
from sklearn.linear_model import LogisticRegression
from sklearn.tree import DecisionTreeClassifier
from xgboost import XGBClassifier
from sklearn.preprocessing import LabelEncoder
from imblearn.over_sampling import SMOTE
from sklearn.metrics import accuracy_score, precision_score, recall_score, f1_score

import mlflow
from mlflow.models import infer_signature
import mlflow.sklearn

import logging

import matplotlib.pyplot as plt
import seaborn as sns

# %%
logging.basicConfig(level=logging.WARN)
logger = logging.getLogger(__name__)

# %%
def eval_metrics(actual, pred):
    rmse = np.sqrt(mean_squared_error(actual, pred))
    mae = mean_absolute_error(actual, pred)
    r2 = r2_score(actual, pred)
    return rmse, mae, r2

# %%
def load_and_process_data():
    # Read the csv files
    data = pd.read_csv('data/application_record.csv')
    record = pd.read_csv('data/credit_record.csv')

    # find all users' account open month.
    begin_month=pd.DataFrame(record.groupby(["ID"])["MONTHS_BALANCE"].agg(min))
    begin_month=begin_month.rename(columns={'MONTHS_BALANCE':'begin_month'}) 

    new_data=pd.merge(data,begin_month,how="left",on="ID") #merge to record datatrain_raw_data.head()

    record['dep_value'] = None
    record.loc[record['STATUS'].isin(['2', '3', '4', '5']), 'dep_value'] = 'Yes'

    cpunt=record.groupby('ID').count()
    cpunt['dep_value'][cpunt['dep_value'] > 0]='Yes' 
    cpunt['dep_value'][cpunt['dep_value'] == 0]='No' 
    cpunt = cpunt[['dep_value']]

    merge_data=pd.merge(new_data,cpunt,how='inner',on='ID')
    return merge_data

# %%
# Counts of each class in the target variable
merge_data = load_and_process_data()
class_counts = merge_data['dep_value'].value_counts()

plt.figure(figsize=(8, 6))
plt.bar(class_counts.index, class_counts.values, color=['blue', 'red'])
plt.xlabel('Credit Approval Status')
plt.ylabel('Count')
plt.title('Distribution of Credit Approval Status')
plt.show()

# %%
def preprocess_data(merge_data):
    # Check for missing values (NaN) in the DataFrame
    print(merge_data.isna().sum())

    # Drop rows with any NaN values
    merge_data.dropna(inplace=True)

    # Display the first few rows of the cleaned DataFrame
    merge_data.head()

    # Now, we remove OCCUPATION_TYPE. As we said, it have too many missed data
    # In addition, we will get rid of FLAG_MOBIL, FLAG_WORK_PHONE, FLAG_PHONE and FLAG_EMAIL. 
    # These parameters do not affect in any way whether a person is creditworthy or not.
    merge_data.drop(['ID','FLAG_WORK_PHONE','FLAG_PHONE','FLAG_EMAIL'], axis=1, inplace=True) 

    # Now, let's convert all non-numeric data to numeric data using LabelEncoder().
    le = LabelEncoder()
    for x in merge_data:
        if merge_data[x].dtypes == 'object':
            merge_data[x] = le.fit_transform(merge_data[x])

    data = merge_data.copy()

    X = data.iloc[:,1:-1] # X value contains all the variables except labels
    y = data.iloc[:,-1] # these are the labels

    # Split the data into training and test sets. (0.70, 0.30) split.
    X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3)

    oversample = SMOTE()
    X_train, y_train = oversample.fit_resample(X_train, y_train)
    X_test, y_test = oversample.fit_resample(X_test, y_test)
    
    return X_train, X_test, y_train, y_test

# %%
def get_experiment_id(experiment_name):
    experiment = mlflow.get_experiment_by_name(experiment_name)
    if experiment:
        return experiment.experiment_id
    else:
        return mlflow.create_experiment(experiment_name)

# %%
def train_models(X_train, X_test, y_train, y_test):
    mlflow.set_tracking_uri("sqlite:///mlflow.db")
    experiment_id = get_experiment_id("creditcard_exp")

    models = [
        {"name": "RandomForest",
         "model": RandomForestClassifier(),
         "parameters": {"n_estimators": [10, 50, 100], "max_depth": [None, 5, 10]}},
        {"name": "LogisticRegression",
         "model": LogisticRegression(),
         "parameters": {"penalty": ["l1", "l2"], "C": [0.1, 1.0, 10.0], "solver": ["liblinear"]}},
        {"name": "DecisionTree",
         "model": DecisionTreeClassifier(),
         "parameters": {"max_depth": [None, 5, 10]}},
        {"name": "GradientBoosting",
         "model": GradientBoostingClassifier(),
         "parameters": {"n_estimators": [50, 100, 150], "learning_rate": [0.01, 0.1, 1.0]}},
        {"name": "XGBoost",
         "model": XGBClassifier(),
         "parameters": {"n_estimators": [50, 100, 150], "learning_rate": [0.01, 0.1, 1.0]}},
        # Add more models here
    ]

    for model_info in models:
        model_name = model_info["name"]
        model = model_info["model"]
        param_grid = model_info["parameters"]

        for parameters in ParameterGrid(param_grid):
            model.set_params(**parameters)
            with mlflow.start_run(experiment_id=experiment_id):
                model.fit(X_train, y_train)

                predicted_classes = model.predict(X_test)

                accuracy = accuracy_score(y_test, predicted_classes)
                precision = precision_score(y_test, predicted_classes)
                recall = recall_score(y_test, predicted_classes)
                f1 = f1_score(y_test, predicted_classes)

                print(f"{model_name} model (parameters={parameters}):")
                print("  Accuracy: %s" % accuracy)
                print("  Precision: %s" % precision)
                print("  Recall: %s" % recall)
                print("  F1 Score: %s" % f1)

                mlflow.log_param("model_name", model_name)
                mlflow.log_params(parameters)
                mlflow.log_metric("accuracy", accuracy)
                mlflow.log_metric("precision", precision)
                mlflow.log_metric("recall", recall)
                mlflow.log_metric("f1", f1)

                predictions = model.predict(X_train)
                signature = infer_signature(X_train, predictions)

                mlflow.sklearn.log_model(model, f"{model_name}_model", signature=signature)

# %%
if __name__ == "__main__":
    warnings.filterwarnings("ignore")
    np.random.seed(40)

    merge_data = load_and_process_data()
    X_train, X_test, y_train, y_test = preprocess_data(merge_data)
    train_models(X_train, X_test, y_train, y_test)
# Out:
# ID                         0
# CODE_GENDER                0
# FLAG_OWN_CAR               0
# FLAG_OWN_REALTY            0
# CNT_CHILDREN               0
# AMT_INCOME_TOTAL           0
# NAME_INCOME_TYPE           0
# NAME_EDUCATION_TYPE        0
# NAME_FAMILY_STATUS         0
# NAME_HOUSING_TYPE          0
# DAYS_BIRTH                 0
# DAYS_EMPLOYED              0
# FLAG_MOBIL                 0
# FLAG_WORK_PHONE            0
# FLAG_PHONE                 0
# FLAG_EMAIL                 0
# OCCUPATION_TYPE        11323
# CNT_FAM_MEMBERS            0
# begin_month                0
# dep_value                  0
# dtype: int64
# RandomForest model (parameters={'max_depth': None, 'n_estimators': 10}):
#   Accuracy: 0.8276721930179269
#   Precision: 0.9915082895268904
#   Recall: 0.6610055263512603
#   F1 Score: 0.7932066316215124
# RandomForest model (parameters={'max_depth': None, 'n_estimators': 50}):
#   Accuracy: 0.8509233050276318
#   Precision: 0.9894717052077459
#   Recall: 0.709394797142472
#   F1 Score: 0.8263463652064689
# RandomForest model (parameters={'max_depth': None, 'n_estimators': 100}):
#   Accuracy: 0.852271195578919
#   Precision: 0.9902457325079722
#   Recall: 0.7115514220245316
#   F1 Score: 0.8280784313725491
# RandomForest model (parameters={'max_depth': 5, 'n_estimators': 10}):
#   Accuracy: 0.7991643078582019
#   Precision: 0.8121220644072563
#   Recall: 0.7784067933683785
#   F1 Score: 0.7949070887818306
# RandomForest model (parameters={'max_depth': 5, 'n_estimators': 50}):
#   Accuracy: 0.8277395875454913
#   Precision: 0.8264196536447845
#   Recall: 0.8297614233724222
#   F1 Score: 0.8280871670702179
# RandomForest model (parameters={'max_depth': 5, 'n_estimators': 100}):
#   Accuracy: 0.8331985442782046
#   Precision: 0.8202902306296969
#   Recall: 0.8533495080199488
#   F1 Score: 0.8364933606394926
# RandomForest model (parameters={'max_depth': 10, 'n_estimators': 10}):
#   Accuracy: 0.8514624612481466
#   Precision: 0.8956152328933394
#   Recall: 0.7956597924248551
#   F1 Score: 0.8426837972876517
# RandomForest model (parameters={'max_depth': 10, 'n_estimators': 50}):
#   Accuracy: 0.8784202722738914
#   Precision: 0.9302681992337165
#   Recall: 0.8181695646313519
#   F1 Score: 0.8706253585771657
# RandomForest model (parameters={'max_depth': 10, 'n_estimators': 100}):
#   Accuracy: 0.8697937727456531
#   Precision: 0.9237065637065637
#   Recall: 0.8061733387248955
#   F1 Score: 0.8609471714409096
# LogisticRegression model (parameters={'C': 0.1, 'penalty': 'l1', 'solver': 'liblinear'}):
#   Accuracy: 0.7482814395471088
#   Precision: 0.7319899244332494
#   Recall: 0.7833939884081412
#   F1 Score: 0.7568201054756168
# LogisticRegression model (parameters={'C': 0.1, 'penalty': 'l2', 'solver': 'liblinear'}):
#   Accuracy: 0.6894460169834209
#   Precision: 0.6796625335549022
#   Recall: 0.7166734061194231
#   F1 Score: 0.6976774701482745
# LogisticRegression model (parameters={'C': 1.0, 'penalty': 'l1', 'solver': 'liblinear'}):
#   Accuracy: 0.7485510176573662
#   Precision: 0.7324174439122763
#   Recall: 0.7832591993530126
#   F1 Score: 0.7569856054191363
# LogisticRegression model (parameters={'C': 1.0, 'penalty': 'l2', 'solver': 'liblinear'}):
#   Accuracy: 0.7097317697802938
#   Precision: 0.7
#   Recall: 0.7340611942310284
#   F1 Score: 0.716626093821962
# LogisticRegression model (parameters={'C': 10.0, 'penalty': 'l1', 'solver': 'liblinear'}):
#   Accuracy: 0.7486184121849306
#   Precision: 0.732451165721487
#   Recall: 0.7833939884081412
#   F1 Score: 0.7570665624592939
# LogisticRegression model (parameters={'C': 10.0, 'penalty': 'l2', 'solver': 'liblinear'}):
#   Accuracy: 0.6901873567866289
#   Precision: 0.6836761260088519
#   Recall: 0.7079121175360561
#   F1 Score: 0.6955830739686114
# DecisionTree model (parameters={'max_depth': None}):
#   Accuracy: 0.7999730421889742
#   Precision: 0.9542763829352929
#   Recall: 0.6301388327267826
#   F1 Score: 0.7590517941224225
# DecisionTree model (parameters={'max_depth': 5}):
#   Accuracy: 0.7257716673406119
#   Precision: 0.6981779460482725
#   Recall: 0.7953902143145977
#   F1 Score: 0.7436204397958539
# DecisionTree model (parameters={'max_depth': 10}):
#   Accuracy: 0.7884485779754684
#   Precision: 0.8554817275747508
#   Recall: 0.6941636339129262
#   F1 Score: 0.7664260733685542
# GradientBoosting model (parameters={'learning_rate': 0.01, 'n_estimators': 50}):
#   Accuracy: 0.7181560857258391
#   Precision: 0.7059946544482627
#   Recall: 0.7476748887990295
#   F1 Score: 0.7262372348782404
# GradientBoosting model (parameters={'learning_rate': 0.01, 'n_estimators': 100}):
#   Accuracy: 0.7704542391157838
#   Precision: 0.7674263627882181
#   Recall: 0.7761153794311901
#   F1 Score: 0.7717464146897199
# GradientBoosting model (parameters={'learning_rate': 0.01, 'n_estimators': 150}):
#   Accuracy: 0.8046232645909153
#   Precision: 0.7984680401479134
#   Recall: 0.8149346273082626
#   F1 Score: 0.8066173037155627
# GradientBoosting model (parameters={'learning_rate': 0.1, 'n_estimators': 50}):
#   Accuracy: 0.8743092060924653
#   Precision: 0.8978510028653295
#   Recall: 0.8447230084917104
#   F1 Score: 0.8704771164664212
# GradientBoosting model (parameters={'learning_rate': 0.1, 'n_estimators': 100}):
#   Accuracy: 0.8940558026688233
#   Precision: 0.9266014883992412
#   Recall: 0.8559105000673946
#   F1 Score: 0.8898542600896862
# GradientBoosting model (parameters={'learning_rate': 0.1, 'n_estimators': 150}):
#   Accuracy: 0.8968863728265265
#   Precision: 0.9413880977364713
#   Recall: 0.8464752662083839
#   F1 Score: 0.8914123491838183
# GradientBoosting model (parameters={'learning_rate': 1.0, 'n_estimators': 50}):
#   Accuracy: 0.9015365952284674
#   Precision: 0.9651780137414117
#   Recall: 0.8331311497506403
#   F1 Score: 0.8943065904651667
# GradientBoosting model (parameters={'learning_rate': 1.0, 'n_estimators': 100}):
#   Accuracy: 0.9400862649952824
#   Precision: 0.9873134328358208
#   Recall: 0.8916295996765062
#   F1 Score: 0.9370352007932572
# GradientBoosting model (parameters={'learning_rate': 1.0, 'n_estimators': 150}):
#   Accuracy: 0.9464213505863324
#   Precision: 0.9909576045063742
#   Recall: 0.9010648335355169
#   F1 Score: 0.9438757500882458
# XGBoost model (parameters={'learning_rate': 0.01, 'n_estimators': 50}):
#   Accuracy: 0.8128453969537673
#   Precision: 0.8143282773564464
#   Recall: 0.8104865884890147
#   F1 Score: 0.8124028913058163
# XGBoost model (parameters={'learning_rate': 0.01, 'n_estimators': 100}):
#   Accuracy: 0.8338050950262839
#   Precision: 0.8405996424150736
#   Recall: 0.8238307049467584
#   F1 Score: 0.8321307011572499
# XGBoost model (parameters={'learning_rate': 0.01, 'n_estimators': 150}):
#   Accuracy: 0.8512602776654535
#   Precision: 0.8656004489337823
#   Recall: 0.8316484701442243
#   F1 Score: 0.8482848697325909
# XGBoost model (parameters={'learning_rate': 0.1, 'n_estimators': 50}):
#   Accuracy: 0.8992451812912792
#   Precision: 0.9511117879987816
#   Recall: 0.8417576492788785
#   F1 Score: 0.8930997497318555
# XGBoost model (parameters={'learning_rate': 0.1, 'n_estimators': 100}):
#   Accuracy: 0.909084782315676
#   Precision: 0.977051241747878
#   Recall: 0.8378487666801455
#   F1 Score: 0.9021116029315724
# XGBoost model (parameters={'learning_rate': 0.1, 'n_estimators': 150}):
#   Accuracy: 0.9123871141663297
#   Precision: 0.9852498017446472
#   Recall: 0.8373096104596307
#   F1 Score: 0.9052754299038182
# XGBoost model (parameters={'learning_rate': 1.0, 'n_estimators': 50}):
#   Accuracy: 0.9088152042054185
#   Precision: 0.9891935483870967
#   Recall: 0.8266612751044615
#   F1 Score: 0.9006534987884571
# XGBoost model (parameters={'learning_rate': 1.0, 'n_estimators': 100}):
#   Accuracy: 0.9102978838118345
#   Precision: 0.9922380336351876
#   Recall: 0.8270656422698477
#   F1 Score: 0.9021539366316255
# XGBoost model (parameters={'learning_rate': 1.0, 'n_estimators': 150}):
#   Accuracy: 0.9108370400323493
#   Precision: 0.9930443222258168
#   Recall: 0.8274700094352339
#   F1 Score: 0.9027277406073082

# %%
experiment_id = get_experiment_id("creditcard_exp")
runs = mlflow.search_runs(experiment_ids=[experiment_id])

# Sort by one of the metrics and get the top run
best_run = runs.sort_values("metrics.f1", ascending=False).iloc[0]

params = best_run.loc[[name.startswith("params.") for name in best_run.index]]
metrics = best_run.loc[[name.startswith("metrics.") for name in best_run.index]]

params
metrics
# Out:
# metrics.f1           0.943876
# metrics.recall       0.901065
# metrics.accuracy     0.946421
# metrics.precision    0.990958
# Name: 9, dtype: object

# %%
# Create a boxplot for F1 scores of each model
plt.figure(figsize=(12, 6))
sns.boxplot(data=runs, x='params.model_name', y='metrics.f1')
plt.title('F1 Scores of Models')
plt.xlabel('Model')
plt.ylabel('F1 Score')
plt.show()
